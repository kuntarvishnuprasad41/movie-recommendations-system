# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
movies = pd.read_csv('datasets/rotten_tomatoes_movies.csv')
reviews = pd.read_csv('datasets/rotten_tomatoes_movie_reviews.csv')

# %%
# Display basic information
print(movies.info())
print(reviews.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143258 entries, 0 to 143257
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    143258 non-null  object
#  1   title                 142891 non-null  object
#  2   audienceScore         73248 non-null   float64
#  3   tomatoMeter           33877 non-null   float64
#  4   rating                13991 non-null   object
#  5   ratingContents        13991 non-null   object
#  6   releaseDateTheaters   30773 non-null   object
#  7   releaseDateStreaming  79420 non-null   object
#  8   runtimeMinutes        129431 non-null  float64
#  9   genre                 132175 non-null  object
#  10  originalLanguage      129400 non-null  object
#  11  director              139041 non-null  object
#  12  writer                90116 non-null   object
#  13  boxOffice             14743 non-null   object
#  14  distributor           23001 non-null   object
#  15  soundMix              15917 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 17.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1444963 entries, 0 to 1444962
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id              1444963 non-null  object
#  1   reviewId        1444963 non-null  int64
#  2   creationDate    1444963 non-null  object
#  3   criticName      1444963 non-null  object
#  4   isTopCritic     1444963 non-null  bool
#  5   originalScore   1009745 non-null  object
#  6   reviewState     1444963 non-null  object
#  7   publicatioName  1444963 non-null  object
#  8   reviewText      1375738 non-null  object
#  9   scoreSentiment  1444963 non-null  object
#  10  reviewUrl       1234038 non-null  object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 111.6+ MB
# None

# %%
reviews
# Out:
#                                         id   reviewId creationDate  \
# 0                                  beavers    1145982   2003-05-23
# 1                               blood_mask    1636744   2007-06-02
# 2        city_hunter_shinjuku_private_eyes    2590987   2019-05-28
# 3        city_hunter_shinjuku_private_eyes    2558908   2019-02-14
# 4                       dangerous_men_2015    2504681   2018-08-29
# ...                                    ...        ...          ...
# 1444958              thor_love_and_thunder  102706151   2022-07-05
# 1444959              thor_love_and_thunder  102706150   2022-07-05
# 1444960              thor_love_and_thunder  102706149   2022-07-05
# 1444961              thor_love_and_thunder  102706148   2022-07-05
# 1444962              thor_love_and_thunder  102706147   2022-07-05
#
#               criticName  isTopCritic originalScore reviewState  \
# 0        Ivan M. Lincoln        False         3.5/4       fresh
# 1          The Foywonder        False           1/5      rotten
# 2           Reuben Baron        False           NaN       fresh
# 3            Matt Schley        False         2.5/5      rotten
# 4              Pat Padua        False           NaN       fresh
# ...                  ...          ...           ...         ...
# 1444958  Christie Cronan        False          7/10       fresh
# 1444959     Ian Sandwell        False           4/5       fresh
# 1444960   Lauren LaMagna        False          8/10       fresh
# 1444961        Jake Cole         True           1/4      rotten
# 1444962      Roger Moore        False         2.5/4       fresh
#
#                         publicatioName  \
# 0        Deseret News (Salt Lake City)
# 1                        Dread Central
# 2                                  CBR
# 3                          Japan Times
# 4                                DCist
# ...                                ...
# 1444958               Raising Whasians
# 1444959                    Digital Spy
# 1444960              Next Best Picture
# 1444961                 Slant Magazine
# 1444962                   Movie Nation
#
#                                                 reviewText scoreSentiment  \
# 0        Timed to be just long enough for most youngste...       POSITIVE
# 1        It doesn't matter if a movie costs 300 million...       NEGATIVE
# 2        The choreography is so precise and lifelike at...       POSITIVE
# 3        The film's out-of-touch attempts at humor may ...       NEGATIVE
# 4        Its clumsy determination is endearing and some...       POSITIVE
# ...                                                    ...            ...
# 1444958  Solid but not totally sold&#44; Thor&#58; Ragn...       POSITIVE
# 1444959  Thor&#58; Love and Thunder is the most enterta...       POSITIVE
# 1444960  &quot;Thor&#58; Love and Thunder&quot; is a st...       POSITIVE
# 1444961  Across Taika Waititi&#8217;s film&#44; a war a...       NEGATIVE
# 1444962  It&#8217;s the jokes that make it&#44; with th...       POSITIVE
#
#                                                  reviewUrl
# 0        http://www.deseretnews.com/article/700003233/B...
# 1        http://www.dreadcentral.com/index.php?name=Rev...
# 2        https://www.cbr.com/city-hunter-shinjuku-priva...
# 3        https://www.japantimes.co.jp/culture/2019/02/0...
# 4        http://dcist.com/2015/11/out_of_frame_dangerou...
# ...                                                    ...
# 1444958  https://raisingwhasians.com/thor-love-and-thun...
# 1444959  https://www.digitalspy.com/movies/a40496050/th...
# 1444960  https://www.nextbestpicture.com/thor-love-and-...
# 1444961  https://www.slantmagazine.com/film/thor-love-a...
# 1444962  https://rogersmovienation.com/2022/07/05/movie...
#
# [1444963 rows x 11 columns]

# %%
# movies_df = movies_df.dropna(subset=['originalLanguage', 'originalScore'])

# %%
import numpy as np

def normalize_score(score):
    try:
        if isinstance(score, str):
            if '/' in score:  # Handle scores like '8/10'
                score = score.strip("'")  # Remove single quotes if present
                value, max_value = map(float, score.split('/'))
                if max_value == 0:
                    raise ValueError("max_value cannot be zero")
                return (value / max_value) * 10
            elif score.replace('.', '').isdigit():  # Handle numeric values with or without decimals
                return float(score)
            elif score.replace('.', '').replace('/', '').isdigit():  # Handle fractions
                score = score.strip("'")  # Remove single quotes if present
                value, max_value = map(float, score.split('/'))
                if max_value == 0:
                    raise ValueError("max_value cannot be zero")
                return (value / max_value) * 10
            else:  # Handle other formats
                grade_to_score = {'A+': 10, 'A': 9, 'A-': 8, 'B+': 7, 'B': 6, 'B-': 5, 'C+': 4, 'C': 3, 'C-': 2, 'D+': 1, 'D': 1, 'D-': 1}
                return grade_to_score.get(score.upper(), np.nan)
        elif isinstance(score, (int, float)):
            return score
        else:
            return np.nan
    except (ValueError, AttributeError, ZeroDivisionError) as e:
        print(f"Error processing score: {score} - {e}")
        return np.nan

# %%
# Apply the normalization
reviews['normalizedScore'] = reviews['originalScore'].apply(normalize_score)

# Remove NaN values
reviews_cleaned = reviews.dropna(subset=['normalizedScore'])
# Out:
# Error processing score: ***1/2 - could not convert string to float: '***1'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 0/0 - max_value cannot be zero
# Error processing score: 2.1/2` - could not convert string to float: '2`'
# Error processing score: 1.5.4 - could not convert string to float: '1.5.4'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 4.5.5 - could not convert string to float: '4.5.5'
# Error processing score: 3/0 - max_value cannot be zero
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 1/2 star - could not convert string to float: '2 star'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 2.5.5 - could not convert string to float: '2.5.5'
# Error processing score: 3.5.4 - could not convert string to float: '3.5.4'
# Error processing score: 3 1/2/4 - could not convert string to float: '3 1'
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 0/0 - max_value cannot be zero
# Error processing score: 2 1/2 - could not convert string to float: '2 1'
# Error processing score: 1.5.5 - could not convert string to float: '1.5.5'
# Error processing score: 7/0 - max_value cannot be zero
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 1.5.4 - could not convert string to float: '1.5.4'
# Error processing score: 1.5.5 - could not convert string to float: '1.5.5'
# Error processing score: **1/2 - could not convert string to float: '**1'
# Error processing score: **1/2 - could not convert string to float: '**1'
# Error processing score: 2/4/ - could not convert string to float: ''
# Error processing score: 2.5.5 - could not convert string to float: '2.5.5'
# Error processing score: 3/5/5 - too many values to unpack (expected 2)
# Error processing score: 3 1/2 - could not convert string to float: '3 1'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 2.5/ - could not convert string to float: ''
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 4 1/2/5 - could not convert string to float: '4 1'
# Error processing score: 2.5/5Too tepid and too predictable of a picture to - could not convert string to float: '5Too tepid and too predictable of a picture to'
# Error processing score: 2/5/4 - too many values to unpack (expected 2)
# Error processing score: 1/8/5 - too many values to unpack (expected 2)
# Error processing score: 0/0 - max_value cannot be zero
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 7.5.10 - could not convert string to float: '7.5.10'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 4 1/2 stars - could not convert string to float: '4 1'
# Error processing score: 1/4ANNAPOL - could not convert string to float: '4ANNAPOL'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: **1/2 - could not convert string to float: '**1'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 1.5.4 - could not convert string to float: '1.5.4'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 2.5.4 - could not convert string to float: '2.5.4'
# Error processing score: 2.5.4 - could not convert string to float: '2.5.4'
# Error processing score: 1.5.4 - could not convert string to float: '1.5.4'
# Error processing score: 2.5.4 - could not convert string to float: '2.5.4'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: B-/C+ - could not convert string to float: 'B-'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3.5.4 - could not convert string to float: '3.5.4'
# Error processing score: 1/4 stars - could not convert string to float: '4 stars'
# Error processing score: 3.5/ - could not convert string to float: ''
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 2'/4 - could not convert string to float: "2'"
# Error processing score: 3 1/2/4 - could not convert string to float: '3 1'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 4.5.5 - could not convert string to float: '4.5.5'
# Error processing score: 4.5.5 - could not convert string to float: '4.5.5'
# Error processing score: ***1/2 - could not convert string to float: '***1'
# Error processing score: 1.5/ - could not convert string to float: ''
# Error processing score: 2.1/2` - could not convert string to float: '2`'
# Error processing score: 2/4 stars - could not convert string to float: '4 stars'
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: * 1/2 - could not convert string to float: '* 1'
# Error processing score: 2.5.4 - could not convert string to float: '2.5.4'
# Error processing score: 21/2 pink ponies out of five - could not convert string to float: '2 pink ponies out of five'
# Error processing score: 2/4 stars - could not convert string to float: '4 stars'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3. 5/5 - could not convert string to float: '3. 5'
# Error processing score: 1/2/5 - too many values to unpack (expected 2)
# Error processing score: 4.5.5 - could not convert string to float: '4.5.5'
# Error processing score: ****1/2 - could not convert string to float: '****1'
# Error processing score: 3/4 stars - could not convert string to float: '4 stars'
# Error processing score: ****1/2 - could not convert string to float: '****1'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3 1/2/4 - could not convert string to float: '3 1'
# Error processing score: 5/5 stars - could not convert string to float: '5 stars'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3/4f - could not convert string to float: '4f'
# Error processing score: 1.5.5 - could not convert string to float: '1.5.5'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 4/5http://www.bbc.co.uk/films/2007/08/27/a_throw_o - could not convert string to float: '5http:'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 61/00 - max_value cannot be zero
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: w.5/4 - could not convert string to float: 'w.5'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: B/B- - could not convert string to float: 'B'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 2.5/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 0/0 - max_value cannot be zero
# Error processing score: 5/10- - could not convert string to float: '10-'
# Error processing score: 2.5.4 - could not convert string to float: '2.5.4'
# Error processing score: ***1/2 - could not convert string to float: '***1'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 2/4The best that can be said about the movie is th - could not convert string to float: '4The best that can be said about the movie is th'
# Error processing score: 1/5/4 - too many values to unpack (expected 2)
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 3 1/2  out of 4 - could not convert string to float: '3 1'
# Error processing score: 2.5.5 - could not convert string to float: '2.5.5'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: * 1/2 - could not convert string to float: '* 1'
# Error processing score: 3/5/4 - too many values to unpack (expected 2)
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 4/5ao - could not convert string to float: '5ao'
# Error processing score: 3.5.4 - could not convert string to float: '3.5.4'
# Error processing score: 3.5/4A - could not convert string to float: '4A'
# Error processing score: 2.5./4 - could not convert string to float: '2.5.'
# Error processing score: 2.5/'5 - could not convert string to float: "'5"
# Error processing score: 3/5 stars - could not convert string to float: '5 stars'
# Error processing score: 3.0/.0 - max_value cannot be zero
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 1.5.4 - could not convert string to float: '1.5.4'
# Error processing score: 2.5.4 - could not convert string to float: '2.5.4'
# Error processing score: 4.5.5 - could not convert string to float: '4.5.5'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 4/5w - could not convert string to float: '5w'
# Error processing score: 4/5 stars - could not convert string to float: '5 stars'
# Error processing score: 21/2/4 - too many values to unpack (expected 2)
# Error processing score: 0/0 - max_value cannot be zero
# Error processing score: 3.5.5 - could not convert string to float: '3.5.5'
# Error processing score: 3.5./4 - could not convert string to float: '3.5.'
# Error processing score: ***1/2 - could not convert string to float: '***1'
# Error processing score: 2/ - could not convert string to float: ''
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 4/0 - max_value cannot be zero
# Error processing score: 2 1/2 stars - could not convert string to float: '2 1'
# Error processing score: 3.5.4.0 - could not convert string to float: '3.5.4.0'
# Error processing score: 2.5/5 stars - could not convert string to float: '5 stars'
# Error processing score: 4 1/2 out of 5 stars - could not convert string to float: '4 1'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 2 1/2 - could not convert string to float: '2 1'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 4..5/5 - could not convert string to float: '4..5'
# Error processing score: 3 1/2 stars - could not convert string to float: '3 1'
# Error processing score: 3/5 stars - could not convert string to float: '5 stars'
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 2. 5 / 5 - could not convert string to float: '2. 5 '
# Error processing score: 1/2/5 - too many values to unpack (expected 2)

# %%
reviews = reviews_cleaned

# %%
reviews.head()
# Out:
#                                   id  reviewId creationDate       criticName  \
# 0                            beavers   1145982   2003-05-23  Ivan M. Lincoln
# 1                         blood_mask   1636744   2007-06-02    The Foywonder
# 3  city_hunter_shinjuku_private_eyes   2558908   2019-02-14      Matt Schley
# 5                 dangerous_men_2015   2299284   2015-12-13       Eric Melin
# 6                 dangerous_men_2015   2295858   2015-11-22      Matt Donato
#
#    isTopCritic originalScore reviewState                 publicatioName  \
# 0        False         3.5/4       fresh  Deseret News (Salt Lake City)
# 1        False           1/5      rotten                  Dread Central
# 3        False         2.5/5      rotten                    Japan Times
# 5        False           4/5       fresh                   Lawrence.com
# 6        False          7/10       fresh            We Got This Covered
#
#                                           reviewText scoreSentiment  \
# 0  Timed to be just long enough for most youngste...       POSITIVE
# 1  It doesn't matter if a movie costs 300 million...       NEGATIVE
# 3  The film's out-of-touch attempts at humor may ...       NEGATIVE
# 5  With every new minute, there's another head-sc...       POSITIVE
# 6  Emotionless reaction shots, zero characterizat...       POSITIVE
#
#                                            reviewUrl  normalizedScore
# 0  http://www.deseretnews.com/article/700003233/B...             8.75
# 1  http://www.dreadcentral.com/index.php?name=Rev...             2.00
# 3  https://www.japantimes.co.jp/culture/2019/02/0...             5.00
# 5  http://www.lawrence.com/weblogs/scenestealers/...             8.00
# 6  http://wegotthiscovered.com/movies/dangerous-m...             7.00

# %%
reviews.shape
# Out:
# (1004642, 12)

# %%
# Check for missing values
print(movies.isnull().sum())
print(reviews.isnull().sum())
# Out:
# id                           0
# title                      367
# audienceScore            70010
# tomatoMeter             109381
# rating                  129267
# ratingContents          129267
# releaseDateTheaters     112485
# releaseDateStreaming     63838
# runtimeMinutes           13827
# genre                    11083
# originalLanguage         13858
# director                  4217
# writer                   53142
# boxOffice               128515
# distributor             120257
# soundMix                127341
# dtype: int64
# id                      0
# reviewId                0
# creationDate            0
# criticName              0
# isTopCritic             0
# originalScore           0
# reviewState             0
# publicatioName          0
# reviewText          68619
# scoreSentiment          0
# reviewUrl          163070
# normalizedScore         0
# dtype: int64

# %%
movies.drop(columns=['rating', 'ratingContents', 'boxOffice', 'distributor', 'soundMix'], inplace=True)
print(movies.isnull().sum())
# Out:
# id                           0
# title                      367
# audienceScore            70010
# tomatoMeter             109381
# releaseDateTheaters     112485
# releaseDateStreaming     63838
# runtimeMinutes           13827
# genre                    11083
# originalLanguage         13858
# director                  4217
# writer                   53142
# dtype: int64

# %%
movies['title'].fillna('Unknown', inplace=True)
movies['audienceScore'].fillna(movies['audienceScore'].median(), inplace=True)
movies['tomatoMeter'].fillna(movies['tomatoMeter'].median(), inplace=True)
movies['releaseDateTheaters'].fillna(movies['releaseDateTheaters'].mode()[0], inplace=True)
movies['releaseDateStreaming'].fillna(movies['releaseDateStreaming'].mode()[0], inplace=True)
movies['runtimeMinutes'].fillna(movies['runtimeMinutes'].median(), inplace=True)
movies['genre'].fillna('Unknown', inplace=True)
movies['originalLanguage'].fillna('Unknown', inplace=True)
movies['director'].fillna('Unknown', inplace=True)
movies['writer'].fillna('Unknown', inplace=True)

# %%
print(movies.isnull().sum())
# Out:
# id                      0
# title                   0
# audienceScore           0
# tomatoMeter             0
# releaseDateTheaters     0
# releaseDateStreaming    0
# runtimeMinutes          0
# genre                   0
# originalLanguage        0
# director                0
# writer                  0
# dtype: int64

# %%
movies
# Out:
#                                                        id  \
# 0                                      space-zombie-bingo
# 1                                         the_green_grass
# 2                                               love_lies
# 3                                    the_sore_losers_1997
# 4                                    dinosaur_island_2002
# ...                                                   ...
# 143253  nadia_the_secret_of_blue_water_the_motion_pict...
# 143254                          everyone_i_knew_and_loved
# 143255                                     the-human-body
# 143256                                       flying_fists
# 143257                                     awakening-2005
#
#                                                     title  audienceScore  \
# 0                                     Space Zombie Bingo!           50.0
# 1                                         The Green Grass           57.0
# 2                                              Love, Lies           43.0
# 3                                             Sore Losers           60.0
# 4                                         Dinosaur Island           70.0
# ...                                                   ...            ...
# 143253  Nadia: The Secret of Blue Water: The Motion Pi...           14.0
# 143254                          Everyone I Knew and Loved           57.0
# 143255                                     The Human Body           71.0
# 143256                                       Flying Fists           57.0
# 143257                                          Awakening           57.0
#
#         tomatoMeter releaseDateTheaters releaseDateStreaming  runtimeMinutes  \
# 0              73.0          2018-09-14           2018-08-25            75.0
# 1              73.0          2018-09-14           2020-02-11           114.0
# 2              73.0          2018-09-14           2017-05-22           120.0
# 3              73.0          2018-09-14           2020-10-23            90.0
# 4              73.0          2018-09-14           2017-03-27            80.0
# ...             ...                 ...                  ...             ...
# 143253         73.0          2002-08-27           2017-05-22            90.0
# 143254         73.0          2018-09-14           2017-05-22            99.0
# 143255         89.0          2018-09-14           2017-05-22            43.0
# 143256         73.0          2018-09-14           2006-11-21            63.0
# 143257         73.0          2018-09-14           2017-05-22            90.0
#
#                                 genre originalLanguage  \
# 0              Comedy, Horror, Sci-fi          English
# 1                               Drama          English
# 2                               Drama           Korean
# 3          Action, Mystery & thriller          English
# 4       Fantasy, Adventure, Animation          English
# ...                               ...              ...
# 143253       Action, Adventure, Anime         Japanese
# 143254                          Drama          English
# 143255                    Documentary          English
# 143256                          Drama          English
# 143257                         Horror          English
#
#                              director                                  writer
# 0                       George Ormrod              George Ormrod,John Sabotta
# 1                     Tiffany Edwards                         Tiffany Edwards
# 2       Park Heung-Sik,Heung-Sik Park  Ha Young-Joon,Jeon Yun-su,Song Hye-jin
# 3               John Michael McCarthy                   John Michael McCarthy
# 4                       Will Meugniot                                John Loy
# ...                               ...                                     ...
# 143253                       Sho Aono                             Kaoru Umeno
# 143254               Andrew Behringer                         Erika Heidewald
# 143255                   Peter Georgi                            Richard Dale
# 143256                 Robert F. Hill             Robert F. Hill,Basil Dickey
# 143257               David J. Francis           David J. Francis,Mike Masters
#
# [143258 rows x 11 columns]

# %%
reviews
# Out:
#                                         id   reviewId creationDate  \
# 0                                  beavers    1145982   2003-05-23
# 1                               blood_mask    1636744   2007-06-02
# 3        city_hunter_shinjuku_private_eyes    2558908   2019-02-14
# 5                       dangerous_men_2015    2299284   2015-12-13
# 6                       dangerous_men_2015    2295858   2015-11-22
# ...                                    ...        ...          ...
# 1444958              thor_love_and_thunder  102706151   2022-07-05
# 1444959              thor_love_and_thunder  102706150   2022-07-05
# 1444960              thor_love_and_thunder  102706149   2022-07-05
# 1444961              thor_love_and_thunder  102706148   2022-07-05
# 1444962              thor_love_and_thunder  102706147   2022-07-05
#
#               criticName  isTopCritic originalScore reviewState  \
# 0        Ivan M. Lincoln        False         3.5/4       fresh
# 1          The Foywonder        False           1/5      rotten
# 3            Matt Schley        False         2.5/5      rotten
# 5             Eric Melin        False           4/5       fresh
# 6            Matt Donato        False          7/10       fresh
# ...                  ...          ...           ...         ...
# 1444958  Christie Cronan        False          7/10       fresh
# 1444959     Ian Sandwell        False           4/5       fresh
# 1444960   Lauren LaMagna        False          8/10       fresh
# 1444961        Jake Cole         True           1/4      rotten
# 1444962      Roger Moore        False         2.5/4       fresh
#
#                         publicatioName  \
# 0        Deseret News (Salt Lake City)
# 1                        Dread Central
# 3                          Japan Times
# 5                         Lawrence.com
# 6                  We Got This Covered
# ...                                ...
# 1444958               Raising Whasians
# 1444959                    Digital Spy
# 1444960              Next Best Picture
# 1444961                 Slant Magazine
# 1444962                   Movie Nation
#
#                                                 reviewText scoreSentiment  \
# 0        Timed to be just long enough for most youngste...       POSITIVE
# 1        It doesn't matter if a movie costs 300 million...       NEGATIVE
# 3        The film's out-of-touch attempts at humor may ...       NEGATIVE
# 5        With every new minute, there's another head-sc...       POSITIVE
# 6        Emotionless reaction shots, zero characterizat...       POSITIVE
# ...                                                    ...            ...
# 1444958  Solid but not totally sold&#44; Thor&#58; Ragn...       POSITIVE
# 1444959  Thor&#58; Love and Thunder is the most enterta...       POSITIVE
# 1444960  &quot;Thor&#58; Love and Thunder&quot; is a st...       POSITIVE
# 1444961  Across Taika Waititi&#8217;s film&#44; a war a...       NEGATIVE
# 1444962  It&#8217;s the jokes that make it&#44; with th...       POSITIVE
#
#                                                  reviewUrl  normalizedScore
# 0        http://www.deseretnews.com/article/700003233/B...             8.75
# 1        http://www.dreadcentral.com/index.php?name=Rev...             2.00
# 3        https://www.japantimes.co.jp/culture/2019/02/0...             5.00
# 5        http://www.lawrence.com/weblogs/scenestealers/...             8.00
# 6        http://wegotthiscovered.com/movies/dangerous-m...             7.00
# ...                                                    ...              ...
# 1444958  https://raisingwhasians.com/thor-love-and-thun...             7.00
# 1444959  https://www.digitalspy.com/movies/a40496050/th...             8.00
# 1444960  https://www.nextbestpicture.com/thor-love-and-...             8.00
# 1444961  https://www.slantmagazine.com/film/thor-love-a...             2.50
# 1444962  https://rogersmovienation.com/2022/07/05/movie...             6.25
#
# [1004642 rows x 12 columns]

# %%
# reviews.drop(columns=[ 'reviewUrl'], inplace=True)

# %%
print(reviews.isnull().sum())
# Out:
# id                      0
# reviewId                0
# creationDate            0
# criticName              0
# isTopCritic             0
# originalScore           0
# reviewState             0
# publicatioName          0
# reviewText          68619
# scoreSentiment          0
# reviewUrl          163070
# normalizedScore         0
# dtype: int64

# %%
# Convert dates with multiple formats and coerce errors
movies['releaseDateTheaters'] = pd.to_datetime(movies['releaseDateTheaters'], errors='coerce')
movies['releaseDateStreaming'] = pd.to_datetime(movies['releaseDateStreaming'], errors='coerce')



# Convert dates to datetime
movies['releaseDateTheaters'] = pd.to_datetime(movies['releaseDateTheaters'])
movies['releaseDateStreaming'] = pd.to_datetime(movies['releaseDateStreaming'])
reviews['creationDate'] = pd.to_datetime(reviews['creationDate'])
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_48804\3770022209.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['creationDate'] = pd.to_datetime(reviews['creationDate'])

# %%
# Descriptive statistics
print(movies.describe())
print(reviews.describe())
# Out:
#        audienceScore    tomatoMeter            releaseDateTheaters  \
# count  143258.000000  143258.000000                         143258
# mean       56.322509      71.290364  2013-09-15 05:31:25.666420224
# min         0.000000       0.000000            1902-10-04 00:00:00
# 25%        57.000000      73.000000            2018-09-14 00:00:00
# 50%        57.000000      73.000000            2018-09-14 00:00:00
# 75%        58.000000      73.000000            2018-09-14 00:00:00
# max       100.000000     100.000000            2032-04-21 00:00:00
# std        17.569599      13.969153                            NaN
#
#                 releaseDateStreaming  runtimeMinutes
# count                         143257   143258.000000
# mean   2015-10-11 14:21:50.813433088       93.543669
# min              1928-12-18 00:00:00        1.000000
# 25%              2016-05-23 00:00:00       85.000000
# 50%              2017-05-22 00:00:00       92.000000
# 75%              2017-05-22 00:00:00      101.000000
# max              2023-12-22 00:00:00     2700.000000
# std                              NaN       26.741998
#            reviewId                   creationDate  normalizedScore
# count  1.004642e+06                        1004642     1.004642e+06
# mean   8.258072e+06  2012-08-04 05:41:39.404962304     3.937573e+01
# min    1.000000e+00            1800-01-01 00:00:00    -2.500000e+00
# 25%    1.524789e+06            2006-07-03 00:00:00     5.000000e+00
# 50%    2.121730e+06            2013-01-10 00:00:00     6.250000e+00
# 75%    2.532462e+06            2018-11-17 00:00:00     8.000000e+00
# max    1.027962e+08            2023-04-08 00:00:00     3.333334e+07
# std    2.449186e+07                            NaN     3.325623e+04

# %%
# Visualization of distributions
plt.figure(figsize=(10, 6))
sns.histplot(movies['audienceScore'].dropna(), bins=20, kde=True)
plt.title('Distribution of Audience Scores')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(movies['tomatoMeter'].dropna(), bins=20, kde=True)
plt.title('Distribution of Tomatometer Scores')
plt.show()
# Out:
# c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting the distribution of score sentiment
plt.figure(figsize=(10, 6))

# Histogram of score sentiment
sns.countplot(x='scoreSentiment', data=reviews, palette='viridis')
plt.title('Distribution of Score Sentiment')
plt.xlabel('Score Sentiment')
plt.ylabel('Count')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Count the occurrences of each sentiment
sentiment_counts = reviews['scoreSentiment'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(10, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(sentiment_counts)))

plt.title('Distribution of Score Sentiment')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Plotting the distributions
plt.figure(figsize=(14, 6))

# Distribution of Audience Scores
plt.subplot(1, 2, 1)
sns.histplot(movies['audienceScore'], kde=True, bins=30, color='blue')
plt.title('Distribution of Audience Scores')
plt.xlabel('Audience Score')
plt.ylabel('Frequency')
# Out:
# c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
from sklearn.utils import resample
# Separate the majority and minority classes
sentiment_counts = reviews['scoreSentiment'].value_counts()
majority_class = sentiment_counts.idxmax()
minority_classes = sentiment_counts.index[sentiment_counts < sentiment_counts.max()]

# Upsample minority classes
reviews_upsampled = reviews[reviews['scoreSentiment'] == majority_class]
for sentiment in minority_classes:
    minority_class_data = reviews[reviews['scoreSentiment'] == sentiment]
    minority_class_upsampled = resample(minority_class_data,
                                        replace=True,  # sample with replacement
                                        n_samples=sentiment_counts.max(),  # to match majority class
                                        random_state=42)  # reproducible results
    reviews_upsampled = pd.concat([reviews_upsampled, minority_class_upsampled])

# Now reviews_upsampled has balanced class distribution
upsampled_sentiment_counts = reviews_upsampled['scoreSentiment'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(10, 6))
plt.pie(upsampled_sentiment_counts, labels=upsampled_sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(upsampled_sentiment_counts)))

plt.title('Upsampled Distribution of Score Sentiment')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Convert releaseDateTheaters to datetime
movies['releaseDateTheaters'] = pd.to_datetime(movies['releaseDateTheaters'], errors='coerce')

# Extract year from releaseDateTheaters
movies['releaseYear'] = movies['releaseDateTheaters'].dt.year

# Fill missing audienceScore values with the median for the purpose of this visualization
movies['audienceScore'].fillna(movies['audienceScore'].median(), inplace=True)

# Filter out movies without a release year
movies = movies.dropna(subset=['releaseYear'])

# Plotting the distribution of audience scores across the years
plt.figure(figsize=(14, 7))

# Boxplot of audience scores by year
sns.boxplot(x='releaseYear', y='audienceScore', data=movies)
plt.xticks(rotation=90)
plt.title('Distribution of Audience Scores Across the Years')
plt.xlabel('Release Year')
plt.ylabel('Audience Score')

plt.tight_layout()
plt.show()

# %%
# Distribution of Critic Scores (Tomatometer)
plt.subplot(1, 2, 2)
sns.histplot(movies['tomatoMeter'], kde=True, bins=30, color='red')
plt.title('Distribution of Critic Scores (Tomatometer)')
plt.xlabel('Critic Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
numeric_columns = movies.select_dtypes(include=['number']).columns

# Generate the correlation matrix
correlation_matrix = movies[numeric_columns].corr()

# Plot the correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# # Correlation heatmap
# plt.figure(figsize=(10, 6))
# sns.heatmap(movies.corr(), annot=True, cmap='coolwarm')
# plt.title('Correlation Heatmap')
# plt.show()

# %%
# Analysis of categorical features
genre_counts = movies['genre'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values)
plt.title('Top 10 Genres')
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting boxplot for distribution of ratings across languages
# plt.figure(figsize=(12, 8))
# sns.boxplot(data=movies, x='originalLanguage', y='originalScore', palette='viridis')
# plt.title('Distribution of Ratings Across Various Languages')
# plt.xlabel('Original Language')
# plt.ylabel('Original Score')
# plt.xticks(rotation=45, ha='right')
# plt.tight_layout()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 # Plotting boxplot for distribution of ratings across languages
#       2 plt.figure(figsize=(12, 8))
# ----> 3 sns.boxplot(data=movies, x='originalLanguage', y='originalScore', palette='viridis')
#       4 plt.title('Distribution of Ratings Across Various Languages')
#       5 plt.xlabel('Original Language')
#
# File c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File c:\Users\vishn\anaconda3\Lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'originalScore'

# %%
# Prepare data for collaborative filtering using the Surprise library
from surprise import Dataset, Reader, SVD
from surprise.model_selection import cross_validate, train_test_split

# reviews['userId'] = reviews['reviewId']

# %%
print(reviews.columns)
# Out:
# Index(['id', 'reviewId', 'creationDate', 'criticName', 'isTopCritic',
#        'originalScore', 'reviewState', 'publicatioName', 'reviewText',
#        'scoreSentiment', 'reviewUrl', 'normalizedScore'],
#       dtype='object')

# %%
reviews
# Out:
#                                         id   reviewId creationDate  \
# 0                                  beavers    1145982   2003-05-23
# 1                               blood_mask    1636744   2007-06-02
# 3        city_hunter_shinjuku_private_eyes    2558908   2019-02-14
# 5                       dangerous_men_2015    2299284   2015-12-13
# 6                       dangerous_men_2015    2295858   2015-11-22
# ...                                    ...        ...          ...
# 1444958              thor_love_and_thunder  102706151   2022-07-05
# 1444959              thor_love_and_thunder  102706150   2022-07-05
# 1444960              thor_love_and_thunder  102706149   2022-07-05
# 1444961              thor_love_and_thunder  102706148   2022-07-05
# 1444962              thor_love_and_thunder  102706147   2022-07-05
#
#               criticName  isTopCritic originalScore reviewState  \
# 0        Ivan M. Lincoln        False         3.5/4       fresh
# 1          The Foywonder        False           1/5      rotten
# 3            Matt Schley        False         2.5/5      rotten
# 5             Eric Melin        False           4/5       fresh
# 6            Matt Donato        False          7/10       fresh
# ...                  ...          ...           ...         ...
# 1444958  Christie Cronan        False          7/10       fresh
# 1444959     Ian Sandwell        False           4/5       fresh
# 1444960   Lauren LaMagna        False          8/10       fresh
# 1444961        Jake Cole         True           1/4      rotten
# 1444962      Roger Moore        False         2.5/4       fresh
#
#                         publicatioName  \
# 0        Deseret News (Salt Lake City)
# 1                        Dread Central
# 3                          Japan Times
# 5                         Lawrence.com
# 6                  We Got This Covered
# ...                                ...
# 1444958               Raising Whasians
# 1444959                    Digital Spy
# 1444960              Next Best Picture
# 1444961                 Slant Magazine
# 1444962                   Movie Nation
#
#                                                 reviewText scoreSentiment  \
# 0        Timed to be just long enough for most youngste...       POSITIVE
# 1        It doesn't matter if a movie costs 300 million...       NEGATIVE
# 3        The film's out-of-touch attempts at humor may ...       NEGATIVE
# 5        With every new minute, there's another head-sc...       POSITIVE
# 6        Emotionless reaction shots, zero characterizat...       POSITIVE
# ...                                                    ...            ...
# 1444958  Solid but not totally sold&#44; Thor&#58; Ragn...       POSITIVE
# 1444959  Thor&#58; Love and Thunder is the most enterta...       POSITIVE
# 1444960  &quot;Thor&#58; Love and Thunder&quot; is a st...       POSITIVE
# 1444961  Across Taika Waititi&#8217;s film&#44; a war a...       NEGATIVE
# 1444962  It&#8217;s the jokes that make it&#44; with th...       POSITIVE
#
#                                                  reviewUrl  normalizedScore
# 0        http://www.deseretnews.com/article/700003233/B...             8.75
# 1        http://www.dreadcentral.com/index.php?name=Rev...             2.00
# 3        https://www.japantimes.co.jp/culture/2019/02/0...             5.00
# 5        http://www.lawrence.com/weblogs/scenestealers/...             8.00
# 6        http://wegotthiscovered.com/movies/dangerous-m...             7.00
# ...                                                    ...              ...
# 1444958  https://raisingwhasians.com/thor-love-and-thun...             7.00
# 1444959  https://www.digitalspy.com/movies/a40496050/th...             8.00
# 1444960  https://www.nextbestpicture.com/thor-love-and-...             8.00
# 1444961  https://www.slantmagazine.com/film/thor-love-a...             2.50
# 1444962  https://rogersmovienation.com/2022/07/05/movie...             6.25
#
# [1004642 rows x 12 columns]

# %%
# Prepare data
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(reviews[['reviewId', 'id', 'normalizedScore']], reader)

# %%
# Train-test split
trainset, testset = train_test_split(data, test_size=0.25)

# %%
algo = SVD()

# Train the model
algo.fit(trainset)

# Evaluate the model
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    5.5879  4.7355  5.0391  74363.27204.5148  14876.629929743.3211
# MAE (testset)     3.7848  3.7781  3.7639  167.26483.7629  36.4709 65.3969
# Fit time          17.40   19.93   18.09   17.85   19.36   18.53   0.95
# Test time         0.89    0.95    0.97    0.92    0.94    0.94    0.03
# {'test_rmse': array([5.58788470e+00, 4.73554162e+00, 5.03908157e+00, 7.43632720e+04,
#         4.51484009e+00]),
#  'test_mae': array([  3.78476379,   3.77808527,   3.76394781, 167.26476768,
#           3.76291566]),
#  'fit_time': (17.400973558425903,
#   19.925355672836304,
#   18.092084646224976,
#   17.852832794189453,
#   19.35742163658142),
#  'test_time': (0.8886408805847168,
#   0.9547252655029297,
#   0.9745724201202393,
#   0.9217076301574707,
#   0.9410078525543213)}

# %%
reviews
# Out:
#                                         id   reviewId creationDate  \
# 0                                  beavers    1145982   2003-05-23
# 1                               blood_mask    1636744   2007-06-02
# 3        city_hunter_shinjuku_private_eyes    2558908   2019-02-14
# 5                       dangerous_men_2015    2299284   2015-12-13
# 6                       dangerous_men_2015    2295858   2015-11-22
# ...                                    ...        ...          ...
# 1444958              thor_love_and_thunder  102706151   2022-07-05
# 1444959              thor_love_and_thunder  102706150   2022-07-05
# 1444960              thor_love_and_thunder  102706149   2022-07-05
# 1444961              thor_love_and_thunder  102706148   2022-07-05
# 1444962              thor_love_and_thunder  102706147   2022-07-05
#
#               criticName  isTopCritic originalScore reviewState  \
# 0        Ivan M. Lincoln        False         3.5/4       fresh
# 1          The Foywonder        False           1/5      rotten
# 3            Matt Schley        False         2.5/5      rotten
# 5             Eric Melin        False           4/5       fresh
# 6            Matt Donato        False          7/10       fresh
# ...                  ...          ...           ...         ...
# 1444958  Christie Cronan        False          7/10       fresh
# 1444959     Ian Sandwell        False           4/5       fresh
# 1444960   Lauren LaMagna        False          8/10       fresh
# 1444961        Jake Cole         True           1/4      rotten
# 1444962      Roger Moore        False         2.5/4       fresh
#
#                         publicatioName  \
# 0        Deseret News (Salt Lake City)
# 1                        Dread Central
# 3                          Japan Times
# 5                         Lawrence.com
# 6                  We Got This Covered
# ...                                ...
# 1444958               Raising Whasians
# 1444959                    Digital Spy
# 1444960              Next Best Picture
# 1444961                 Slant Magazine
# 1444962                   Movie Nation
#
#                                                 reviewText scoreSentiment  \
# 0        Timed to be just long enough for most youngste...       POSITIVE
# 1        It doesn't matter if a movie costs 300 million...       NEGATIVE
# 3        The film's out-of-touch attempts at humor may ...       NEGATIVE
# 5        With every new minute, there's another head-sc...       POSITIVE
# 6        Emotionless reaction shots, zero characterizat...       POSITIVE
# ...                                                    ...            ...
# 1444958  Solid but not totally sold&#44; Thor&#58; Ragn...       POSITIVE
# 1444959  Thor&#58; Love and Thunder is the most enterta...       POSITIVE
# 1444960  &quot;Thor&#58; Love and Thunder&quot; is a st...       POSITIVE
# 1444961  Across Taika Waititi&#8217;s film&#44; a war a...       NEGATIVE
# 1444962  It&#8217;s the jokes that make it&#44; with th...       POSITIVE
#
#                                                  reviewUrl  normalizedScore
# 0        http://www.deseretnews.com/article/700003233/B...             8.75
# 1        http://www.dreadcentral.com/index.php?name=Rev...             2.00
# 3        https://www.japantimes.co.jp/culture/2019/02/0...             5.00
# 5        http://www.lawrence.com/weblogs/scenestealers/...             8.00
# 6        http://wegotthiscovered.com/movies/dangerous-m...             7.00
# ...                                                    ...              ...
# 1444958  https://raisingwhasians.com/thor-love-and-thun...             7.00
# 1444959  https://www.digitalspy.com/movies/a40496050/th...             8.00
# 1444960  https://www.nextbestpicture.com/thor-love-and-...             8.00
# 1444961  https://www.slantmagazine.com/film/thor-love-a...             2.50
# 1444962  https://rogersmovienation.com/2022/07/05/movie...             6.25
#
# [1004642 rows x 12 columns]

# %%
# Generate recommendations for a user
user_id = '1145982'
top_n = 100

# Get a list of all movie ids
movie_ids = movies['id'].unique()

# Predict ratings for all movies
predictions = [algo.predict(user_id, movie_id) for movie_id in movie_ids]

# Sort by estimated rating
recommendations = sorted(predictions, key=lambda x: x.est, reverse=True)[:top_n]

# Display top 10 recommendations
for rec in recommendations:
    print(f"Movie ID: {rec.iid}, Estimated Rating: {rec.est}")
# Out:
# Movie ID: space-zombie-bingo, Estimated Rating: 10
# Movie ID: the_green_grass, Estimated Rating: 10
# Movie ID: love_lies, Estimated Rating: 10
# Movie ID: the_sore_losers_1997, Estimated Rating: 10
# Movie ID: dinosaur_island_2002, Estimated Rating: 10
# Movie ID: adrift_2018, Estimated Rating: 10
# Movie ID: malta-con-huevo-scrambled-beer, Estimated Rating: 10
# Movie ID: kakabakaba-ka-ba, Estimated Rating: 10
# Movie ID: sundowning, Estimated Rating: 10
# Movie ID: 1035316-born_to_kill, Estimated Rating: 10
# Movie ID: 1015331-number_one_with_a_bullet, Estimated Rating: 10
# Movie ID: garden_murder_case, Estimated Rating: 10
# Movie ID: margarita_happy_hour, Estimated Rating: 10
# Movie ID: leap_of_faith_2019, Estimated Rating: 10
# Movie ID: shake-rattle-roll-3, Estimated Rating: 10
# Movie ID: daag_1973, Estimated Rating: 10
# Movie ID: crown_vs_stevens_1936, Estimated Rating: 10
# Movie ID: 1221483-paa, Estimated Rating: 10
# Movie ID: f9ab9165-598c-3ac9-bc3e-a5fb2ac517e5, Estimated Rating: 10
# Movie ID: the_last_gentleman, Estimated Rating: 10
# Movie ID: sarah_palin_you_betcha, Estimated Rating: 10
# Movie ID: 1005521-death_of_a_salesman, Estimated Rating: 10
# Movie ID: escape_from_alcatraz, Estimated Rating: 10
# Movie ID: sheffey, Estimated Rating: 10
# Movie ID: wrong_guy, Estimated Rating: 10
# Movie ID: cold_room, Estimated Rating: 10
# Movie ID: s_diary, Estimated Rating: 10
# Movie ID: deck_the_halls_2011, Estimated Rating: 10
# Movie ID: alraune, Estimated Rating: 10
# Movie ID: danger_tomorrow, Estimated Rating: 10
# Movie ID: angry_rice_wives, Estimated Rating: 10
# Movie ID: a_state_of_mind_2005, Estimated Rating: 10
# Movie ID: mugavaree, Estimated Rating: 10
# Movie ID: the_moth, Estimated Rating: 10
# Movie ID: standardized_lies_money_and_civil_rights_how_testing_is_ruining_public_education, Estimated Rating: 10
# Movie ID: outpatient, Estimated Rating: 10
# Movie ID: cupid, Estimated Rating: 10
# Movie ID: the_in_laws_1979, Estimated Rating: 10
# Movie ID: isteve, Estimated Rating: 10
# Movie ID: campfire_christmas, Estimated Rating: 10
# Movie ID: gimme_the_power_2012, Estimated Rating: 10
# Movie ID: disciple_of_death, Estimated Rating: 10
# Movie ID: de_lhuile_sur_le_feu, Estimated Rating: 10
# Movie ID: snuff_bottle_connection, Estimated Rating: 10
# Movie ID: tripping_with_nils_frahm, Estimated Rating: 10
# Movie ID: haunted_3d, Estimated Rating: 10
# Movie ID: the_walls_of_the_moon, Estimated Rating: 10
# Movie ID: beg1994, Estimated Rating: 10
# Movie ID: top_of_the_heap, Estimated Rating: 10
# Movie ID: gun_shy_2017, Estimated Rating: 10
# Movie ID: island_of_love, Estimated Rating: 10
# Movie ID: sunset_strip-1991, Estimated Rating: 10
# Movie ID: uncle_tom, Estimated Rating: 10
# Movie ID: the_awakening, Estimated Rating: 10
# Movie ID: la_deuda, Estimated Rating: 10
# Movie ID: pitra_putra_aur_dharamyuddha, Estimated Rating: 10
# Movie ID: shem_the_penman_sings_again, Estimated Rating: 10
# Movie ID: new_orleans_politics, Estimated Rating: 10
# Movie ID: johnny_cool, Estimated Rating: 10
# Movie ID: starting_at_zero_reimagining_education_in_america, Estimated Rating: 10
# Movie ID: sufi_paranja_katha, Estimated Rating: 10
# Movie ID: father_2018, Estimated Rating: 10
# Movie ID: the_pagan_1929, Estimated Rating: 10
# Movie ID: race_the_sun, Estimated Rating: 10
# Movie ID: steve-harvey-still-trippin, Estimated Rating: 10
# Movie ID: 10010327-seed, Estimated Rating: 10
# Movie ID: the_immature, Estimated Rating: 10
# Movie ID: angel_guts_nami, Estimated Rating: 10
# Movie ID: toorbos, Estimated Rating: 10
# Movie ID: truth_about_love, Estimated Rating: 10
# Movie ID: moglie_e_marito, Estimated Rating: 10
# Movie ID: watch_out_were_mad_2022, Estimated Rating: 10
# Movie ID: blood_mask, Estimated Rating: 10
# Movie ID: white_on_white, Estimated Rating: 10
# Movie ID: bet_to_basic_2000, Estimated Rating: 10
# Movie ID: shot_in_the_dark, Estimated Rating: 10
# Movie ID: under_heat, Estimated Rating: 10
# Movie ID: nipawistamasowin_we_will_stand_up, Estimated Rating: 10
# Movie ID: darwin_conspiracy, Estimated Rating: 10
# Movie ID: limo, Estimated Rating: 10
# Movie ID: prison_girls, Estimated Rating: 10
# Movie ID: one_summer_night_in_town, Estimated Rating: 10
# Movie ID: paul_blart_mall_cop, Estimated Rating: 10
# Movie ID: how_to_disappear_completely, Estimated Rating: 10
# Movie ID: take-her-shes-mine, Estimated Rating: 10
# Movie ID: 2112, Estimated Rating: 10
# Movie ID: tolerance_1989, Estimated Rating: 10
# Movie ID: not_without_my_daughter, Estimated Rating: 10
# Movie ID: monsoon_wedding, Estimated Rating: 10
# Movie ID: between_kings_and_queens_2012, Estimated Rating: 10
# Movie ID: distiller, Estimated Rating: 10
# Movie ID: dr_knock_2017, Estimated Rating: 10
# Movie ID: 33_days_2014, Estimated Rating: 10
# Movie ID: 10009299-falling, Estimated Rating: 10
# Movie ID: the_soong_sisters, Estimated Rating: 10
# Movie ID: sleigh_bells_ring, Estimated Rating: 10
# Movie ID: rewind_2003, Estimated Rating: 10
# Movie ID: standstill, Estimated Rating: 10
# Movie ID: the_railway_station_man, Estimated Rating: 10
# Movie ID: nice_people, Estimated Rating: 10
